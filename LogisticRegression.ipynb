# %% [markdown]
# <a href="https://colab.research.google.com/github/harshvgangawane/PWSA4/blob/main/LogisticRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python program that loads a dataset, splits it into training and testing sets, applies Logistic
# Regression, and prints the model accuracy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_iris

# %%
data=load_iris()

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['Target']=data.target

# %%
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 0         0
# ...

# %%
df=df[df['Target']!=2]

# %%
X=df.iloc[:,:-1]

# %%
y=df.iloc[:,-1]

# %%
X
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# ..                ...               ...                ...               ...
# 95                5.7               3.0                4.2               1.2
# 96                5.7               2.9                4.2               1.3
# 97                6.2               2.9                4.3               1.3
# 98                5.1               2.5                3.0               1.1
# 99                5.7               2.8                4.1               1.3
#
# [100 rows x 4 columns]

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: Target, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 15                5.7               4.4                1.5               0.4
# 40                5.0               3.5                1.3               0.3
# 96                5.7               2.9                4.2               1.3
# 9                 4.9               3.1                1.5               0.1
# 72                6.3               2.5                4.9               1.5
# ..                ...               ...                ...               ...
# 60                5.0               2.0                3.5               1.0
# 71                6.1               2.8                4.0               1.3
# 14                5.8               4.0                1.2               0.2
# 92                5.8               2.6                4.0               1.2
# 51                6.4               3.2                4.5               1.5
#
# [75 rows x 4 columns]

# %%
X_test
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 83                6.0               2.7                5.1               1.6
# 53                5.5               2.3                4.0               1.3
# 70                5.9               3.2                4.8               1.8
# 45                4.8               3.0                1.4               0.3
# 44                5.1               3.8                1.9               0.4
# 39                5.1               3.4                1.5               0.2
# 22                4.6               3.6                1.0               0.2
# 80                5.5               2.4                3.8               1.1
# 10                5.4               3.7                1.5               0.2
# 0                 5.1               3.5                1.4               0.2
# 18                5.7               3.8                1.7               0.3
# ...

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)*100

# %%
accuracy
# Out:
# 100.0

# %% [markdown]
# Write a Python program to apply L1 regularization (Lasso) on a dataset using LogisticRegression(penalty='l1')
# and print the model accuracy

# %%
# Apply L1 regularization (Lasso) using Logistic Regression
model_l1 = LogisticRegression(penalty='l1', solver='liblinear') # Specify solver for l1 penalty
model_l1.fit(X_train, y_train)

# Make predictions on the test set
y_pred_l1 = model_l1.predict(X_test)

# Calculate and print the model accuracy
accuracy_l1 = accuracy_score(y_test, y_pred_l1) * 100
print(f"Accuracy with L1 regularization: {accuracy_l1:.2f}%")
# Out:
# Accuracy with L1 regularization: 100.00%

# %% [markdown]
#  Write a Python program to train Logistic Regression with L2 regularization (Ridge) using
# LogisticRegression(penalty='l2'). Print model accuracy and coefficients

# %%
model_l2 = LogisticRegression(penalty='l2', solver='liblinear') # Specify solver for l2 penalty
model_l2.fit(X_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
y_pred_l2 = model_l2.predict(X_test)

# %%
accuracy_l2=accuracy_score(y_test,y_pred_l2)*100

# %%
accuracy_l2
# Out:
# 100.0

# %%
for i, col_name in enumerate(X_train.columns):
    print(f"The coefficient for {col_name} is {model_l2.coef_[0][i]}") # Access coefficients correctly
# Out:
# The coefficient for sepal length (cm) is -0.36949723705912074
# The coefficient for sepal width (cm) is -1.3744681443332367
# The coefficient for petal length (cm) is 2.116092523327558
# The coefficient for petal width (cm) is 0.9574828518326162

# %% [markdown]
#  Write a Python program to train Logistic Regression with Elastic Net Regularization (penalty='elasticnet')

# %%
model_en = LogisticRegression(penalty='elasticnet', solver='saga', l1_ratio=0.5)
model_en.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(l1_ratio=0.5, penalty='elasticnet', solver='saga')

# %%
y_pred_en = model_en.predict(X_test)
accuracy_en = accuracy_score(y_test, y_pred_en) * 100

# %%
accuracy_en
# Out:
# 100.0

# %% [markdown]
# Write a Python program to train a Logistic Regression model for multiclass classification using
# multi_class='ovr'

# %%
model_ovr = LogisticRegression(multi_class='ovr', solver='liblinear')
model_ovr.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:1256: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. Use OneVsRestClassifier(LogisticRegression(..)) instead. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
y_pred_ovr = model_ovr.predict(X_test)
accuracy_ovr = accuracy_score(y_test, y_pred_ovr) * 100

# %%
accuracy_ovr
# Out:
# 100.0

# %% [markdown]
# Write a Python program to apply GridSearchCV to tune the hyperparameters (C and penalty) of Logistic
# Regression. Print the best parameters and accuracy

# %%
from sklearn.model_selection import GridSearchCV
best_param={ 'C':[0.01,0.1,1,10,100], 'penalty':["l1","l2"]}
model=LogisticRegression()
grid_search=GridSearchCV(model,best_param,cv=5,scoring="accuracy")
grid_search.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 25 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
grid_search.best_params_
# Out:
# {'C': 0.01, 'penalty': 'l2'}

# %%
grid_search.best_score_
# Out:
# 1.0

# %% [markdown]
# Write a Python program to load a dataset from a CSV file, apply Logistic Regression, and evaluate its
# accuracy

# %%
df1 = pd.read_csv('/content/sample_data/framingham.csv')

# %%
X1=df1.iloc[:,:-1]

# %%
y1=df1.iloc[:,-1]

# %%
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,test_size=0.25,random_state=42)

# %%
X1_train
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3076     0   43        1.0              1        10.0     0.0
# 1187     1   50        1.0              1        20.0     0.0
# 3259     0   37        4.0              0         0.0     0.0
# 2823     1   48        1.0              1        20.0     0.0
# 2031     0   64        1.0              0         0.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 3444     0   36        1.0              1         5.0     0.0
# 466      0   57        3.0              1        15.0     0.0
# 3092     0   60        2.0              0         0.0     0.0
# 3772     1   39        2.0              1        10.0     0.0
# 860      0   35        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3076                0             0         0    269.0  139.0   96.0  24.38
# ...

# %%
X1_test
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3188     1   63        1.0              0         0.0     0.0
# 764      1   45        3.0              0         0.0     0.0
# 3264     0   51        1.0              1         2.0     0.0
# 1967     1   45        3.0              1        30.0     0.0
# 2185     0   45        2.0              1         3.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 2285     1   48        2.0              0         0.0     0.0
# 1833     0   42        3.0              0         0.0     0.0
# 3734     0   45        2.0              1         3.0     0.0
# 1411     0   36        3.0              0         0.0     0.0
# 2157     1   54        1.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3188                0             1         0    190.0  148.0   90.0  27.13
# ...

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
X1_train=imputer.fit_transform(X1_train)
X1_test=imputer.transform(X1_test)

# %%
lr=LogisticRegression()
lr.fit(X1_train,y1_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y1_pred=lr.predict(X1_test)

# %%
accuracy_score(y1_test,y1_pred)*100
# Out:
# 86.13207547169812

# %% [markdown]
# M Write a Python program to apply RandomizedSearchCV for tuning hyperparameters (C, penalty, solver) in
# Logistic Regression. Print the best parameters and accuracy

# %%
from sklearn.model_selection import RandomizedSearchCV
best_param={ 'C':[0.01,0.1,1,10,100], 'penalty':["l1","l2"],'solver':['liblinear','saga']}

# %%
lr1=LogisticRegression()

# %%
lr_random=RandomizedSearchCV(lr1,best_param,cv=5,scoring="accuracy")

# %%
lr_random.fit(X1_train,y1_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
lr_random.best_params_
# Out:
# {'solver': 'liblinear', 'penalty': 'l1', 'C': 100}

# %%
lr_random.best_score_
# Out:
# 0.8489610260981528

# %% [markdown]
# Write a Python program to implement One-vs-One (OvO) Multiclass Logistic Regression and print accuracy

# %%
from sklearn.multiclass import OneVsOneClassifier
one=OneVsOneClassifier(LogisticRegression())
one.fit(X1_train,y1_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# OneVsOneClassifier(estimator=LogisticRegression())

# %%
y_pred_one=one.predict(X1_test)

# %%
accuracy_score(y1_test,y_pred_one)*100
# Out:
# 86.13207547169812

# %% [markdown]
# Write a Python program to train a Logistic Regression model and visualize the confusion matrix for binary
# classification

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y1_test,y1_pred)

# %%
cm
# Out:
# array([[903,   5],
#        [142,  10]])

# %%
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Write a Python program to train a Logistic Regression model and evaluate its performance using Precision,
# Recall, and F1-Score

# %%
from sklearn.metrics import classification_report
print(classification_report(y1_test,y1_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92       908
#            1       0.67      0.07      0.12       152
#
#     accuracy                           0.86      1060
#    macro avg       0.77      0.53      0.52      1060
# weighted avg       0.84      0.86      0.81      1060

# %% [markdown]
# Write a Python program to train Logistic Regression on the Titanic dataset, handle missing values, and
# evaluate performance

# %%
df2=pd.read_csv('/content/sample_data/titanic - titanic (2).csv')

# %%
df2.shape
# Out:
# (891, 12)

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2['Age']=df2['Age'].fillna(df2['Age'].median())

# %%
df2['Age'].isnull().sum()
# Out:
# 0

# %%
df2['Embarked'].fillna(df2['Embarked'].mode()[0],inplace=True)

# %%
df2['Embarked'].isnull().sum()
# Out:
# 0

# %%
df2['Cabin']=df2['Cabin'].fillna(df2['Cabin'].mode()[0])

# %%
df2['Cabin']
# Out:
# 0      B96 B98
# 1          C85
# 2      B96 B98
# 3         C123
# 4      B96 B98
#         ...
# 886    B96 B98
# 887        B42
# 888    B96 B98
# 889       C148
# 890    B96 B98
# Name: Cabin, Length: 891, dtype: object

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df2.sample()
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 385          386         0       2  Davies, Mr. Charles Henry  male  18.0
#
#      SibSp  Parch        Ticket  Fare    Cabin Embarked
# 385      0      0  S.O.C. 14879  73.5  B96 B98        S

# %%
df2['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df2['Embarked']=df2['Embarked'].map({'S':0,'C':1,'Q':2})

# %%
# !pip install category_encoders

# %%
import category_encoders as ce
encoder = ce.OneHotEncoder(cols=['Name', 'Sex', 'Ticket', 'Cabin'], use_cat_names=True, handle_unknown='return_nan', return_df=True) #use_cat_names=True to keep the column names

# %%
df2 = encoder.fit_transform(df2)

# %%
X2=df2.drop('Survived',axis=1)
y2=df2['Survived']

# %%
y2.unique()
# Out:
# array([0, 1])

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.25, random_state=42)

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
X2_train=imputer.fit_transform(X2_train)
X2_test=imputer.transform(X2_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Embarked']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/impute/_base.py:635: UserWarning: Skipping features without any observed values: ['Embarked']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
psg=LogisticRegression()
psg.fit(X2_train,y2_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred=psg.predict(X2_test)

# %%
accuracy_score(y2_test,y_pred)*100
# Out:
# 83.40807174887892

# %% [markdown]
# Write a Python program to apply feature scaling (Standardization) before training a Logistic Regression
# model. Evaluate its accuracy and compare results with and without scaling

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer


# Initialize StandardScaler
scaler = StandardScaler()
model_scaled = LogisticRegression()
model_scaled.fit(X_train_scaled, y_train)

# Make predictions on the scaled test data
y_pred_scaled = model_scaled.predict(X_test_scaled)

# Calculate accuracy for the scaled data
accuracy_scaled = accuracy_score(y_test, y_pred_scaled) * 100
print(f"Accuracy with feature scaling: {accuracy_scaled:.2f}%")

# Compare with the original accuracy (without scaling) - already calculated as 'accuracy'
print(f"Original accuracy (without scaling): {accuracy:.2f}%")
# Out:
# Accuracy with feature scaling: 86.60%
# Original accuracy (without scaling): 100.00%

# %%
X_train = imputer.fit_transform(X_train) # Fit and transform on X_train
X_test = imputer.transform(X_test)       # Transform X_test using the fitted imputer

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform the testing data (using the same scaler fitted on training data)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
#  Write a Python program to train Logistic Regression and evaluate its performance using ROC-AUC score

# %%
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y2_test, y_pred)
print(f"ROC-AUC score: {roc_auc:.2f}")
# Out:
# ROC-AUC score: 0.82

# %% [markdown]
# M Write a Python program to train Logistic Regression using a custom learning rate (C=0.5) and evaluate
# accuracy

# %%
model_custom_c = LogisticRegression(C=0.5)
model_custom_c.fit(X_train, y_train)
y_pred_custom_c = model_custom_c.predict(X_test)
accuracy_custom_c = accuracy_score(y_test, y_pred_custom_c) * 100
print(f"Accuracy with custom learning rate (C=0.5): {accuracy_custom_c:.2f}%")
# Out:
# Accuracy with custom learning rate (C=0.5): 86.04%
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Write a Python program to train Logistic Regression and identify important features based on model
# coefficients

# %%
coefficients = model_l2.coef_[0]
feature_names = data.feature_names  # Assuming 'data' is your original dataset
# or
# feature_names = df.columns[:-1]
feature_importance = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})
feature_importance = feature_importance.sort_values(by='Coefficient', ascending=False)
feature_importance
# Out:
#              Feature  Coefficient
# 2  petal length (cm)     2.116093
# 3   petal width (cm)     0.957483
# 0  sepal length (cm)    -0.369497
# 1   sepal width (cm)    -1.374468

# %% [markdown]
# Write a Python program to train Logistic Regression and visualize the Precision-Recall Curve for binary
# classification

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

# Assuming 'psg' is your trained Logistic Regression model and 'X2_test', 'y2_test' are your test data
# as in the provided code.

y_score = psg.predict_proba(X2_test)[:, 1] # Probability estimates for the positive class

precision, recall, thresholds = precision_recall_curve(y2_test, y_score)

average_precision = average_precision_score(y2_test, y_score)

plt.plot(recall, precision, label=f'Average Precision = {average_precision:.2f}')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
#  Write a Python program to train Logistic Regression with different solvers (liblinear, saga, lbfgs) and compare
# their accuracy

# %%
solvers = ['liblinear', 'saga', 'lbfgs']
for solver in solvers:
    model = LogisticRegression(solver=solver, max_iter=1000) # Increased max_iter
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred) * 100
    print(f"Accuracy with solver {solver}: {accuracy:.2f}%")
# Out:
# Accuracy with solver liblinear: 86.51%
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Accuracy with solver saga: 86.13%
# Accuracy with solver lbfgs: 86.51%
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
