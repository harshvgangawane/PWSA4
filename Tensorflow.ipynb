# %% [markdown]
# <a href="https://colab.research.google.com/github/harshvgangawane/PWSA4/blob/main/Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.How do you install and verify that TensorFlow 2.0 was installed successfully

# %%
# !pip install tensorflow==2.0.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.0.0 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.0.post1, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0, 2.18.1, 2.19.0rc0, 2.19.0)
# ERROR: No matching distribution found for tensorflow==2.0.0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# 2.How can you define a simple function in TensorFlow 2.0 to perform addition

# %%
def add(x,y):
  return tf.add(x,y)
t1=tf.constant([1,2,3])
t2=tf.constant([4,5,6])
result=add(t1,t2)
print(result)
# Out:
# tf.Tensor([5 7 9], shape=(3,), dtype=int32)

# %% [markdown]
# 3.How can you create a simple neural network in TensorFlow 2.0 with one hidden layer

# %%
# prompt: How can you create a simple neural network in TensorFlow 2.0 with one hidden layer

import tensorflow as tf

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Example usage (assuming you have training data 'x_train' and 'y_train'):
# model.fit(x_train, y_train, epochs=10)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Dense(128,activation='relu')
])

# %% [markdown]
# How can you create a simple neural network in TensorFlow 2.0 with one hidden layer

# %%
# prompt: How can you create a simple neural network in TensorFlow 2.0 with one hidden layer

# Define the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)), # Hidden layer with 128 neurons and ReLU activation
  tf.keras.layers.Dense(10, activation='softmax') # Output layer with 10 neurons (e.g., for 10 classes) and softmax activation
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Example usage (assuming you have training data 'x_train' and 'y_train'):
# model.fit(x_train, y_train, epochs=10)

# %% [markdown]
# How can you visualize the training progress using TensorFlow and Matplotlib

# %%
# prompt: How can you visualize the training progress using TensorFlow and Matplotlib

import matplotlib.pyplot as plt
import numpy as np

# Generate random data for demonstration purposes
num_samples = 1000
num_features = 784
num_classes = 10

x_train = np.random.rand(num_samples, num_features)
y_train = np.random.randint(0, num_classes, num_samples)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)  # Convert to one-hot encoding


# Assuming you have training data x_train and y_train and you've compiled the model
history = model.fit(x_train, y_train, epochs=10, validation_split=0.2) # Include validation data

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f7d193d93e00> in <cell line: 0>()
#      15
#      16 # Assuming you have training data x_train and y_train and you've compiled the model
# ---> 17 history = model.fit(x_train, y_train, epochs=10, validation_split=0.2) # Include validation data
#      18
#      19 # Plot training & validation accuracy values
#
# /usr/local/lib/python3.11/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/trainer.py in _assert_compile_called(self, method_name)
# ...

# %%
# prompt: How can you visualize the training progress using TensorFlow and Matplotlib

import matplotlib.pyplot as plt
import numpy as np

# Generate random data for demonstration purposes
num_samples = 1000
num_features = 784
num_classes = 10

x_train = np.random.rand(num_samples, num_features)
y_train = np.random.randint(0, num_classes, num_samples)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)  # Convert to one-hot encoding

# Define the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu', input_shape=(784,)), # Hidden layer with 128 neurons and ReLU activation
  tf.keras.layers.Dense(10, activation='softmax') # Output layer with 10 neurons (e.g., for 10 classes) and softmax activation
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Assuming you have training data x_train and y_train and you've compiled the model
history = model.fit(x_train, y_train, epochs=10, validation_split=0.2) # Include validation data

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.1196 - loss: 2.4248 - val_accuracy: 0.1200 - val_loss: 2.3847
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1311 - loss: 2.2835 - val_accuracy: 0.0850 - val_loss: 2.3620
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1876 - loss: 2.2306 - val_accuracy: 0.0950 - val_loss: 2.3784
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2061 - loss: 2.1917 - val_accuracy: 0.0850 - val_loss: 2.3469
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2494 - loss: 2.1130 - val_accuracy: 0.0650 - val_loss: 2.4471
# Epoch 6/10
# ...

# %% [markdown]
# How do you install PyTorch and verify the PyTorch installation

# %%
# prompt: How do you install PyTorch and verify the PyTorch installation

# !pip3 install torch torchvision torchaudio

import torch

print(torch.__version__)
print(torch.cuda.is_available()) # Check CUDA availability
print(torch.version.cuda) # Check CUDA version (if available)
x = torch.rand(5, 3)
x
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 91.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %% [markdown]
# How do you create a simple neural network in PyTorch

# %%
# prompt: How do you create a simple neural network in PyTorch

import torch
import torch.nn as nn
import torch.nn.functional as F

# Define the neural network architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 128)  # Input layer (784 features) to hidden layer (128 neurons)
        self.fc2 = nn.Linear(128, 10)   # Hidden layer to output layer (10 classes)

    def forward(self, x):
        x = F.relu(self.fc1(x))  # Apply ReLU activation to the hidden layer
        x = self.fc2(x)          # Output layer (no activation here, as we'll use CrossEntropyLoss)
        return x

# Create an instance of the network
net = Net()

# Example usage (assuming you have input data 'input_data'):
# input_data = torch.randn(1, 784) # Example input data
# output = net(input_data)

# To train this network, you'd need to define a loss function, an optimizer, and a training loop.
# Example loss function and optimizer:
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# How do you define a loss function and optimizer in PyTorch

# %%
# prompt: How do you define a loss function and optimizer in PyTorch

# Define the loss function (e.g., CrossEntropyLoss for classification)
criterion = nn.CrossEntropyLoss()

# Define the optimizer (e.g., Adam)
optimizer = torch.optim.Adam(net.parameters(), lr=0.001) # lr is the learning rate

# %% [markdown]
# How do you implement a custom loss function in PyTorch

# %%
# prompt: How do you implement a custom loss function in PyTorch

# How do you implement a custom loss function in PyTorch

import torch
import torch.nn as nn

# Define the custom loss function
class CustomLoss(nn.Module):
    def __init__(self):
        super(CustomLoss, self).__init__()

    def forward(self, output, target):
        # Calculate the custom loss based on output and target
        # Example: Mean Squared Error (MSE)
        loss = torch.mean((output - target)**2)
        return loss

# Create an instance of the custom loss function
custom_loss = CustomLoss()

# Example usage within a training loop
# ... (your model, optimizer, and data loaders) ...

# Inside the training loop:
# outputs = model(inputs)  # Forward pass
# loss = custom_loss(outputs, labels)  # Calculate the custom loss
# loss.backward() # Backpropagate the loss
# optimizer.step() # Update model parameters

# %% [markdown]
# How do you save and load a TensorFlow model?

# %%
# prompt: How do you save and load a TensorFlow model?

# Save the model
model.save('my_model.keras') # Add the .keras extension to the filename

# Load the model
loaded_model = tf.keras.models.load_model('my_model.keras') # Add the .keras extension when loading as well
